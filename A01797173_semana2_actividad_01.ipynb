# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('MNA_NLP_semana_02_Actividad_datos.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
docs=[re.sub(r'[\r\n]+', '', text) for text in docs]

# %%
docs[0:10]
# Out:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.']

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
# Se busca e imprime todas las palabras con dos o mas signos
[text for text in docs if re.search(r'!{2,}', text)]
# Out:
# ['If you want a sandwich just go to any Firehouse!!!!!',
#  'This place receives stars for their APPETIZERS!!!',
#  'All I have to say is the food was amazing!!!',
#  'Best breakfast buffet!!!',
#  'Sooooo good!!',
#  "Don't do it!!!!",
#  'DELICIOUS!!',
#  'This is the place where I first had pho and it was amazing!!',
#  'Favorite place in town for shawarrrrrrma!!!!!!',
#  'First - the bathrooms at this location were dirty- Seat covers were not replenished & just plain yucky!!!',
#  '"Classy/warm atmosphere, fun and fresh appetizers, succulent steaks (Baseball steak!!!!!"',
#  'It was delicious!!!',
#  'Best tacos in town by far!!',
#  'We loved the biscuits!!!',
#  'Boy was that sucker dry!!.',
#  'Very disappointing!!!',
#  'A fantastic neighborhood gem !!!',
#  'Have been going since 2007 and every meal has been awesome!!',
#  '2 Thumbs Up!!',
#  'A FLY was in my apple juice.. A FLY!!!!!!!!',
#  '"I\'m so happy to be here!!!"""',
#  'This place is great!!!!!!!!!!!!!!',
# ...

# %%
results = []

for text in docs:
    for match in re.finditer(r'(\b\w+)(!{2,})', text):
        word = match.group(1)
        exclamations = match.group(2)
        count = len(exclamations)
        
        results.append((text, count))

print(results)
# Out:
# [('If you want a sandwich just go to any Firehouse!!!!!', 5), ('This place receives stars for their APPETIZERS!!!', 3), ('All I have to say is the food was amazing!!!', 3), ('Best breakfast buffet!!!', 3), ('Sooooo good!!', 2), ("Don't do it!!!!", 4), ('DELICIOUS!!', 2), ('This is the place where I first had pho and it was amazing!!', 2), ('Favorite place in town for shawarrrrrrma!!!!!!', 6), ('First - the bathrooms at this location were dirty- Seat covers were not replenished & just plain yucky!!!', 3), ('"Classy/warm atmosphere, fun and fresh appetizers, succulent steaks (Baseball steak!!!!!"', 5), ('It was delicious!!!', 3), ('Best tacos in town by far!!', 2), ('We loved the biscuits!!!', 3), ('Boy was that sucker dry!!.', 2), ('Very disappointing!!!', 3), ('Have been going since 2007 and every meal has been awesome!!', 2), ('2 Thumbs Up!!', 2), ('A FLY was in my apple juice.. A FLY!!!!!!!!', 8), ('"I\'m so happy to be here!!!"""', 3), ('This place is great!!!!!!!!!!!!!!', 14), ('
# ...

# %%
print("El número de resultados que se obtuvieron es",len(results))
# Out:
# El número de resultados que se obtuvieron es 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
results = []
for text in docs:
    words = re.findall(r'\b[A-Z]+\b', text)
    for word in words:
     results.append((word, text))
results
# Out:
# [('I', 'Now I am getting angry and I want my damn pho.'),
#  ('I', 'Now I am getting angry and I want my damn pho.'),
#  ('THAT', "Honeslty it didn't taste THAT fresh.)"),
#  ('A', 'A great touch.'),
#  ('I',
#   'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.'),
#  ('I', '"I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!"'),
#  ('I', 'I was disgusted because I was pretty sure that was human hair.'),
#  ('I', 'I was disgusted because I was pretty sure that was human hair.'),
#  ('I', 'I was shocked because no signs indicate cash only.'),
#  ('I', 'I could care less... The interior is just beautiful.'),
#  ('I', 'I found this place by accident and I could not be happier.'),
#  ('I', 'I found this place by accident and I could not be happier.'),
#  ('I', '"Overall, I like this place a lot."'),
#  ('I',
#   '"Poor service, the waiter made me feel like I was stupid every time he came to the table."'),
# ...

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 455

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
results = []
for text in docs:
    if re.fullmatch(r'[A-Z\s!]+', text):
        results.append((text))
        
results
# Out:
# ['DELICIOUS!!', 'AVOID THIS ESTABLISHMENT!']

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 2

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
results = []
for text in docs:
    words = re.findall(r'[áéíóúÁÉÍÓÚ]', text)
    for word in words:
     results.append((word, text))
results
# Out:
# []

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 0

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
results = []
for text in docs:
    words = re.findall(r'\$\d+(?:\.\d+)?', text)
    for word in words:
     results.append((word, text))
results
# Out:
# [('$20',
#   '"And considering the two of us left there very full and happy for about $20, you just can\'t go wrong."'),
#  ('$4.00',
#   '"I go to far too many places and I\'ve never seen any restaurant that serves a 1 egg breakfast, especially for $4.00."'),
#  ('$17',
#   '"The burger... I got the ""Gold Standard"" a $17 burger and was kind of disappointed."'),
#  ('$3', 'Definitely not worth the $3 I paid.'),
#  ('$35', 'Very Very Disappointed ordered the $35 Big Bay Plater.'),
#  ('$7.85',
#   "Paying $7.85 for a hot dog and fries that looks like it came out of a kid's meal at the Wienerschnitzel is not my idea of a good meal."),
#  ('$12',
#   '"The sangria was about half of a glass wine full and was $12, ridiculous."'),
#  ('$11.99',
#   'The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).')]

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
results = []
for text in docs:
    words = re.findall(r'\blove\w*\b', text)
    for word in words:
     results.append((word))
results
# Out:
# ['loved',
#  'love',
#  'loves',
#  'lovers',
#  'love',
#  'lovers',
#  'loved',
#  'loved',
#  'love',
#  'love',
#  'love',
#  'loved',
#  'love',
#  'loved',
#  'love',
#  'lovely',
#  'love',
#  'lovely',
#  'love',
#  'lover',
#  'loved',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love']

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 29

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
results = []
for text in docs:
    words = re.findall(r'\bso{2,}|\bgo{3,}d', text)
    for word in words:
     results.append((word))
results
# Out:
# ['soo',
#  'soooo',
#  'soo',
#  'soo',
#  'goood',
#  'soo',
#  'soo',
#  'soooooo',
#  'soo',
#  'soo',
#  'soooo',
#  'soo',
#  'soo']

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 13

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
results = []
for text in docs:
    words = re.findall(r'\b[A-Za-z]{10}\b', text)
    for word in words:
     results.append((word))
results
# Out:
# ['overpriced',
#  'restaurant',
#  'restaurant',
#  'refreshing',
#  'sunglasses',
#  'absolutely',
#  'restaurant',
#  'APPETIZERS',
#  'definitely',
#  'apparently',
#  'Everything',
#  'experience',
#  'Tigerlilly',
#  'personable',
#  'restaurant',
#  'definitely',
#  'atmosphere',
#  'experience',
#  'Phenomenal',
#  'Definitely',
#  'overpriced',
#  'management',
#  'selections',
#  'restaurant',
#  'highlights',
#  'everything',
#  'reasonably',
#  'Restaurant',
#  'waitresses',
#  'Everything',
#  'vegetarian',
#  'atmosphere',
#  'definitely',
#  'absolutely',
#  'overcooked',
#  'incredible',
#  'EXPERIENCE',
#  'uninspired',
#  'experience',
#  'flavourful',
#  'restaurant',
#  'privileged',
#  'complaints',
#  'godfathers',
#  'restaurant',
#  'atmosphere',
#  'absolutely',
#  'proclaimed',
#  'restaurant',
#  'definitely',
#  'incredible',
#  'convenient',
#  'incredibly',
#  'everything',
#  'delightful',
#  'reasonable',
#  'restaurant',
#  'especially',
# ...

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 218

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
results = []
for text in docs:
    words = re.findall(r'\b[A-Z][a-z]*[a-z]\b', text)
    
    # ignorar la primera palabra del string
    results.extend(words[1:])

results
# Out:
# ['Loved',
#  'May',
#  'Rick',
#  'Steve',
#  'Cod',
#  'Vegas',
#  'Burrittos',
#  'Blah',
#  'Mexican',
#  'Luke',
#  'Our',
#  'Hiro',
#  'Firehouse',
#  'Greek',
#  'Greek',
#  'Heart',
#  'Attack',
#  'Grill',
#  'Vegas',
#  'Dos',
#  'Gringos',
#  'Jeff',
#  'Bad',
#  'Customer',
#  'Service',
#  'Vegas',
#  'Rice',
#  'Company',
#  'Hard',
#  'Rock',
#  'Casino',
#  'Buffet',
#  'Tigerlilly',
#  'Thai',
#  'Not',
#  'Vegas',
#  'Lox',
#  'Subway',
#  'Subway',
#  'Vegas',
#  'Vegas',
#  'Mandalay',
#  'Bay',
#  'Great',
#  'Phoenix',
#  'Vegas',
#  'Khao',
#  'Soi',
#  'Valley',
#  'Phoenix',
#  'Magazine',
#  'Pho',
#  'Fridays',
#  'Tasty',
#  'Jamaican',
#  'Bisque',
#  'Bussell',
#  'Sprouts',
#  'Risotto',
#  'Filet',
#  'Otto',
#  'Yeah',
#  'Not',
#  'Also',
#  'Vegas',
#  'Greek',
#  'Veggitarian',
#  'Madison',
#  'Ironman',
#  'Pho',
#  'Burger',
#  'Pizza',
#  'Salads',
#  'They',
#  'Bachi',
#  'Service',
#  'English',
#  'Pizza',
#  'Hut',
#  'Seat',
#  'Gold',
# ...

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 229

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
results = []
for text in docs:
    words = re.findall(r'\b[A-Za-z]+(?:-[A-Za-z]+)+\b', text)
    if words: 
        results.extend(words)

results
# Out:
# ['flat-lined',
#  'hands-down',
#  'must-stop',
#  'sub-par',
#  'Service-check',
#  'in-house',
#  'been-stepped-in-and-tracked-everywhere',
#  'multi-grain',
#  'to-go',
#  'non-customer',
#  'High-quality',
#  'sit-down',
#  'over-whelm',
#  'low-key',
#  'non-fancy',
#  'golden-crispy',
#  'over-priced',
#  'over-hip',
#  'under-services']

# %%
print("Número de resultados es", len(results))
# Out:
# Número de resultados es 19

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
import re

results1 = []
results2 = []

for text in docs:
    words_ing = re.findall(r'\b\w+ing\b', text)
    words_ed = re.findall(r'\b\w+ed\b', text)
    results1.extend(words_ing)
    results2.extend(words_ed)

results1, results2
# Out:
# (['during',
#   'getting',
#   'being',
#   'being',
#   'amazing',
#   'running',
#   'redeeming',
#   'getting',
#   'thing',
#   'dressing',
#   'refreshing',
#   'running',
#   'amazing',
#   'nothing',
#   'appalling',
#   'wasting',
#   'eating',
#   'going',
#   'Coming',
#   'experiencing',
#   'underwhelming',
#   'eating',
#   'raving',
#   'spring',
#   'unsatisfying',
#   'amazing',
#   'Everything',
#   'disappointing',
#   'dining',
#   'flirting',
#   'thing',
#   'coming',
#   'playing',
#   'ordering',
#   'arriving',
#   'disappointing',
#   'preparing',
#   'loving',
#   'liking',
#   'reviewing',
#   'venturing',
#   'including',
#   'during',
#   'changing',
#   'going',
#   'considering',
#   'coming',
#   'going',
#   'everything',
#   'looking',
#   'dressing',
#   'dining',
#   'Everything',
#   'amazing',
#   'judging',
#   'maintaining',
#   'asking',
#   'having',
#   'something',
#   'lacking',
#   'Interesting',
#   'preparing',
#   'missing',
# ...

# %%
print("El número de palabras con ING son", len(results1))
print("El número de palabras con ING son", len(results2))
# Out:
# El número de palabras con ING son 279
# El número de palabras con ING son 334

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
clean_text = []

for text in docs:
    clean = re.sub(r'[^A-Za-z\s]', '', text)  # quitar símbolos
    clean = clean.lower()                     # minúsculas
    clean = re.sub(r'\s+', ' ', clean).strip()  # limpiar espacios
    
    clean_text.append(clean)

# %%
clean_text[0:10]
# Out:
# ['wow loved this place',
#  'crust is not good',
#  'not tasty and the texture was just nasty',
#  'stopped by during the late may bank holiday off rick steve recommendation and loved it',
#  'the selection on the menu was great and so were the prices',
#  'now i am getting angry and i want my damn pho',
#  'honeslty it didnt taste that fresh',
#  'the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer',
#  'the fries were great too',
#  'a great touch']

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
# tokenización
tokenized_docs = [text.split() for text in clean_text]

# total de tokens
total_tokens = sum(len(doc) for doc in tokenized_docs)

print(tokenized_docs)
# Out:
# [['wow', 'loved', 'this', 'place'], ['crust', 'is', 'not', 'good'], ['not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty'], ['stopped', 'by', 'during', 'the', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'and', 'loved', 'it'], ['the', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices'], ['now', 'i', 'am', 'getting', 'angry', 'and', 'i', 'want', 'my', 'damn', 'pho'], ['honeslty', 'it', 'didnt', 'taste', 'that', 'fresh'], ['the', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer'], ['the', 'fries', 'were', 'great', 'too'], ['a', 'great', 'touch'], ['service', 'was', 'very', 'prompt'], ['would', 'not', 'go', 'back'], ['the', 'cashier', 'had', 'no', 'care', 'what', 'so', 'ever', 'on', 'what', 'i', 'had', 'to', 'say', 'it', 'still', 'ended', 'up', 'being', 'wayyy', 'overpriced'], ['i', 'tried', '
# ...

# %%
print("Total tokens:", total_tokens)
# Out:
# Total tokens: 10777

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
stopwords_set = set(mis_stopwords)

filtered_docs = [
    [word for word in doc if word not in stopwords_set]
    for doc in tokenized_docs
]

print(filtered_docs)
# Out:
# [['wow', 'loved', 'place'], ['crust', 'not', 'good'], ['not', 'tasty', 'texture', 'nasty'], ['stopped', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'loved'], ['selection', 'menu', 'great', 'prices'], ['getting', 'angry', 'want', 'damn', 'pho'], ['honeslty', 'didnt', 'taste', 'fresh'], ['potatoes', 'like', 'rubber', 'could', 'tell', 'made', 'ahead', 'time', 'kept', 'warmer'], ['fries', 'great'], ['great', 'touch'], ['service', 'prompt'], ['would', 'not', 'go', 'back'], ['cashier', 'no', 'care', 'ever', 'say', 'still', 'ended', 'wayyy', 'overpriced'], ['tried', 'cape', 'cod', 'ravoli', 'chickenwith', 'cranberrymmmm'], ['disgusted', 'pretty', 'sure', 'human', 'hair'], ['shocked', 'no', 'signs', 'indicate', 'cash'], ['highly', 'recommended'], ['waitress', 'little', 'slow', 'service'], ['place', 'not', 'worth', 'time', 'let', 'alone', 'vegas'], ['not', 'like'], ['burrittos', 'blah'], ['food', 'amazing'], ['service', 'also', 'cute'], ['could', 'care', 'less'
# ...

# %%
total_tokens = sum(len(doc) for doc in tokenized_docs)
print("Número total de tokens",total_tokens)
# Out:
# Número total de tokens 10777

# %%
vocabulario = set(word for doc in filtered_docs for word in doc)

total_unicos = len(vocabulario)

print("Número total de tokens unicos",total_unicos)
# Out:
# Número total de tokens unicos 1941

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Este ejercicio permitió comprender la importancia del preprocesamiento en el análisis de texto. La limpieza, tokenización y eliminación de stopwords no solo reducen la complejidad de los datos, sino que también mejoran la calidad de la información que será utilizada en modelos posteriores. Además, el cálculo de métricas como el número de tokens y el vocabulario ayuda a dimensionar el corpus y su diversidad léxica.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
